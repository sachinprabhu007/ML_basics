# %%
import pandas as pd

# %%
df = pd.read_excel('Veg_price_in_india.xlsx')

# %%
df.head()
# Out:
#      datesk        Item Name                 Date  price
# 0  20110101   Kashini greens  2011-01-01 00:00:00    NaN
# 1  20110101  Pineapple juice  2011-01-01 00:00:00    NaN
# 2  20110101    Thiland Juice  2011-01-01 00:00:00    NaN
# 3  20110101    Thiland Jelly  2011-01-01 00:00:00    NaN
# 4  20110101     Orange juice  2011-01-01 00:00:00    NaN

# %%
df.tail()
# Out:
#           datesk          Item Name        Date  price
# 868960  20180227       Komark fruit  27/02/2018   28.0
# 868961  20180227          Dry dates  27/02/2018   20.0
# 868962  20180227  Tamarind seedless  27/02/2018  230.0
# 868963  20180227    Dry fruit mixed  27/02/2018    NaN
# 868964  20180227  Tender Coconut(S)  27/02/2018   25.0

# %%
df.shape
# Out:
# (868965, 4)

# %%
df.columns.tolist()
# Out:
# ['datesk', 'Item Name', 'Date', 'price']

# %%
df.describe()
# Out:
#              datesk          price
# count  8.689650e+05  551948.000000
# mean   2.014152e+07      51.664567
# std    2.062121e+04      68.496674
# min    2.011010e+07       0.000000
# 25%    2.012101e+07       0.000000
# 50%    2.014073e+07      30.000000
# 75%    2.016051e+07      67.000000
# max    2.018023e+07     863.000000

# %%
df.max()
# Out:
# datesk    20180227.0
# price          863.0
# dtype: float64

# %%
df['price'].max()
# Out:
# 863.0

# %%
df['price'].mean()
# Out:
# 51.664567223732085

# %%
df['datesk'].value_counts()
# Out:
# 20131226    333
# 20111003    333
# 20111001    333
# 20161206    333
# 20120226    333
# 20111002    333
# 20161205    333
# 20120225    333
# 20161204    333
# 20161207    333
# 20120224    333
# 20160204    333
# 20130522    333
# 20161227    333
# 20160715    333
# 20160205    333
# 20120227    333
# 20120228    333
# 20161226    333
# 20170929    333
# 20161214    333
# 20160702    333
# 20161213    333
# 20160701    333
# 20170928    333
# 20161212    333
# 20111004    333
# 20111007    333
# 20161203    333
# 20111005    333
#            ...
# 20170207    331
# 20170719    331
# 20170704    331
# 20170705    331
# 20170706    331
# 20170707    331
# 20140325    331
# 20141001    331
# 20170714    331
# 20170202    331
# 20170214    331
# 20170407    331
# 20170211    331
# 20170723    331
# 20170212    331
# 20170724    331
# 20170213    331
# 20170725    331
# 20170530    331
# 20170726    331
# 20170713    331
# 20170215    331
# 20170727    331
# 20141002    331
# ...

# %%
df.iloc[[df['price'].argmax()]]
# Out:
# /home/sachin/.virtualenvs/keras_tf_p3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
#           datesk  Item Name        Date  price
# 813795  20170915  Peas Ooty  15/09/2017  863.0

# %%
df.iloc[[df['price'].argmax()]]['price']
# Out:
# /home/sachin/.virtualenvs/keras_tf_p3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# 813795    863.0
# Name: price, dtype: float64

# %%
type(df.iloc[[df['price'].argmax()]]['price'])
# Out:
# /home/sachin/.virtualenvs/keras_tf_p3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# pandas.core.series.Series

# %%
type(df.iloc[[df['price'].argmax()]])
# Out:
# /home/sachin/.virtualenvs/keras_tf_p3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# pandas.core.frame.DataFrame

# %%
df.iloc[[df['price'].argmax()]]['price'][813795]
# Out:
# /home/sachin/.virtualenvs/keras_tf_p3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# 863.0

# %%
df.iloc[:3]
# Out:
#      datesk        Item Name                 Date  price
# 0  20110101   Kashini greens  2011-01-01 00:00:00    NaN
# 1  20110101  Pineapple juice  2011-01-01 00:00:00    NaN
# 2  20110101    Thiland Juice  2011-01-01 00:00:00    NaN

# %%
df.loc[:3]
# Out:
#      datesk        Item Name                 Date  price
# 0  20110101   Kashini greens  2011-01-01 00:00:00    NaN
# 1  20110101  Pineapple juice  2011-01-01 00:00:00    NaN
# 2  20110101    Thiland Juice  2011-01-01 00:00:00    NaN
# 3  20110101    Thiland Jelly  2011-01-01 00:00:00    NaN

# %%
df.loc[df['price'].argmax(),'price']
# Out:
# /home/sachin/.virtualenvs/keras_tf_p3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# 863.0

# %%
df.at[df['price'].argmax(),'price']
# Out:
# /home/sachin/.virtualenvs/keras_tf_p3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# 863.0

# %%
df.sort_values('price').head()
# Out:
#           datesk              Item Name        Date  price
# 666729  20160628                  Dates  28/06/2016    0.0
# 281169  20130424   Ber fruit/Bore fruit  24/04/2013    0.0
# 281172  20130424            Apple Simla  24/04/2013    0.0
# 281173  20130424        Apple Australia  24/04/2013    0.0
# 636808  20160330  Chillies Bajji yagani  30/03/2016    0.0

# %%
df.groupby('price')

# %%
df[df['price']>20]
# Out:
#           datesk                Item Name                 Date  price
# 296     20110101             Sponge Gourd  2011-01-01 00:00:00   32.0
# 22312   20110309        Baby corn cleaned  2011-09-03 00:00:00   56.0
# 22315   20110309        Chilakarive green  2011-09-03 00:00:00   22.0
# 22318   20110309           Chakota greens  2011-09-03 00:00:00   21.0
# 22320   20110309             Arive greens  2011-09-03 00:00:00   24.0
# 22322   20110309              Chikadi kai  2011-09-03 00:00:00   30.0
# 22323   20110309           Garlic cleaned  2011-09-03 00:00:00  140.0
# 22324   20110309                   Garlic  2011-09-03 00:00:00   92.0
# 22326   20110309                   Ginger  2011-09-03 00:00:00   22.0
# 22328   20110309         Ground nut Local  2011-09-03 00:00:00   56.0
# 22329   20110309             Double Beans  2011-09-03 00:00:00   32.0
# 22330   20110309       Double Beans seeds  2011-09-03 00:00:00   96.0
# ...

# %%
df[(df['price'] > 40) & (df['price'] < 100)]
# Out:
#           datesk                      Item Name                 Date  price
# 22312   20110309              Baby corn cleaned  2011-09-03 00:00:00   56.0
# 22324   20110309                         Garlic  2011-09-03 00:00:00   92.0
# 22328   20110309               Ground nut Local  2011-09-03 00:00:00   56.0
# 22330   20110309             Double Beans seeds  2011-09-03 00:00:00   96.0
# 22342   20110309                     Lime Local  2011-09-03 00:00:00   52.0
# 22344   20110309                   Ladys finger  2011-09-03 00:00:00   43.0
# 22346   20110309                    Grapes T.S.  2011-09-03 00:00:00   80.0
# 22349   20110309                         Jukani  2011-09-03 00:00:00   80.0
# 22367   20110309                    Orange malt  2011-09-03 00:00:00   50.0
# 22369   20110309           Guava Allahabad(Red)  2011-09-03 00:00:00   45.0
# 22387   20110309                  Apple Economy  2011-09-03 00:00:00   95.0
# ...

# %%
df.groupby('Item Name')['price'].mean().head()
# Out:
# Item Name
# Amla                       56.359863
# Anjura/Fig                 57.066090
# Apple Australia            71.581088
# Apple Chaina Delicious    132.000000
# Apple Chilli               43.308083
# Name: price, dtype: float64

# %%
df.groupby('Item Name')['price'].mean().head(2)
# Out:
# Item Name
# Amla          56.359863
# Anjura/Fig    57.066090
# Name: price, dtype: float64

# %%
df.values
# Out:
# array([[20110101, 'Kashini greens', datetime.datetime(2011, 1, 1, 0, 0),
#         nan],
#        [20110101, 'Pineapple juice', datetime.datetime(2011, 1, 1, 0, 0),
#         nan],
#        [20110101, 'Thiland Juice', datetime.datetime(2011, 1, 1, 0, 0),
#         nan],
#        ...,
#        [20180227, 'Tamarind seedless', '27/02/2018', 230.0],
#        [20180227, 'Dry fruit mixed', '27/02/2018', nan],
#        [20180227, 'Tender Coconut(S)', '27/02/2018', 25.0]], dtype=object)

# %%
for index, row in df.iterrows():
    print(row)
    if index == 1:
        break

# %%
df[['Item Name','price']].head()
# Out:
#          Item Name  price
# 0   Kashini greens    NaN
# 1  Pineapple juice    NaN
# 2    Thiland Juice    NaN
# 3    Thiland Jelly    NaN
# 4     Orange juice    NaN

# %%
df.loc[:,['Item Name','price']].head()
# Out:
#          Item Name  price
# 0   Kashini greens    NaN
# 1  Pineapple juice    NaN
# 2    Thiland Juice    NaN
# 3    Thiland Jelly    NaN
# 4     Orange juice    NaN

# %%
type(df['Item Name'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Item Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[0:3]
# Out:
#      datesk        Item Name                 Date  price
# 0  20110101   Kashini greens  2011-01-01 00:00:00    NaN
# 1  20110101  Pineapple juice  2011-01-01 00:00:00    NaN
# 2  20110101    Thiland Juice  2011-01-01 00:00:00    NaN

# %%
df.iloc[0:3,:]

# %%
df.isnull().sum()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ax = df['price'].plot.hist(bins=20)
ax.set_xlabel('price range')
# Out:
# Text(0.5,0,'price range')

# %%
print(df.groupby('Item Name')['price'].mean().head())
ax = df.groupby('Item Name')['price'].mean().head().plot.hist(bins=10)
ax.set_xlabel('price range - Mean')
# Out:
# Item Name
# Amla                       56.359863
# Anjura/Fig                 57.066090
# Apple Australia            71.581088
# Apple Chaina Delicious    132.000000
# Apple Chilli               43.308083
# Name: price, dtype: float64
# Text(0.5,0,'price range - Mean')
